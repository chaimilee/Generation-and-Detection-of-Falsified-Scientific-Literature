# %% [markdown]
# # **DCGAN**

# %%
#Code Block 1 - Libraries
import os
import time
import tensorflow as tf
import numpy as np
from glob import glob
import datetime
import random
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Code Block 2 - Mount Google Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#Code Block 3
# !unzip /content/drive/MyDrive/Colab_Notebooks/celeb_images_base.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: celeb_images_base/100k/100k/132927.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._132927.jpg
#   inflating: celeb_images_base/100k/100k/109999.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._109999.jpg
#   inflating: celeb_images_base/100k/100k/099346.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099346.jpg
#   inflating: celeb_images_base/100k/100k/073947.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._073947.jpg
#   inflating: celeb_images_base/100k/100k/166386.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._166386.jpg
#   inflating: celeb_images_base/100k/100k/081509.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._081509.jpg
#   inflating: celeb_images_base/100k/100k/043884.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._043884.jpg
#   inflating: celeb_images_base/100k/100k/052751.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._052751.jpg
#   inflating: celeb_images_base/100k/100k/156245.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156245.jpg
#   inflating: celeb_images_base/100k/100k/014704.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014704.jpg
#   inflating: celeb_images_base/100k/100k/176195.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._176195.jpg
#   inflating: celeb_images_base/100k/100k/141739.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._141739.jpg
#   inflating: celeb_images_base/100k/100k/003278.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._003278.jpg
#   inflating: celeb_images_base/100k/100k/118894.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._118894.jpg
#   inflating: celeb_images_base/100k/100k/137877.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._137877.jpg
#   inflating: celeb_images_base/100k/100k/087178.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._087178.jpg
#   inflating: celeb_images_base/100k/100k/002166.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._002166.jpg
#   inflating: celeb_images_base/100k/100k/140427.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._140427.jpg
#   inflating: celeb_images_base/100k/100k/044133.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._044133.jpg
#   inflating: celeb_images_base/100k/100k/158268.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._158268.jpg
#   inflating: celeb_images_base/100k/100k/129491.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._129491.jpg
#   inflating: celeb_images_base/100k/100k/106472.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._106472.jpg
#   inflating: celeb_images_base/100k/100k/147348.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._147348.jpg
#   inflating: celeb_images_base/100k/100k/167098.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167098.jpg
#   inflating: celeb_images_base/100k/100k/054320.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054320.jpg
#   inflating: celeb_images_base/100k/100k/098058.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._098058.jpg
#   inflating: celeb_images_base/100k/100k/184303.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._184303.jpg
#   inflating: celeb_images_base/100k/100k/060085.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._060085.jpg
#   inflating: celeb_images_base/100k/100k/057629.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._057629.jpg
#   inflating: celeb_images_base/100k/100k/009033.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._009033.jpg
#   inflating: celeb_images_base/100k/100k/115368.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._115368.jpg
#   inflating: celeb_images_base/100k/100k/155994.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._155994.jpg
#   inflating: celeb_images_base/100k/100k/190376.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._190376.jpg
#   inflating: celeb_images_base/100k/100k/144641.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._144641.jpg
#   inflating: celeb_images_base/100k/100k/040355.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._040355.jpg
#   inflating: celeb_images_base/100k/100k/102614.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._102614.jpg
#   inflating: celeb_images_base/100k/100k/165857.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._165857.jpg
#   inflating: celeb_images_base/100k/100k/019220.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._019220.jpg
#   inflating: celeb_images_base/100k/100k/070296.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._070296.jpg
#   inflating: celeb_images_base/100k/100k/084471.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084471.jpg
#   inflating: celeb_images_base/100k/100k/112407.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._112407.jpg
#   inflating: celeb_images_base/100k/100k/050146.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050146.jpg
#   inflating: celeb_images_base/100k/100k/180165.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._180165.jpg
#   inflating: celeb_images_base/100k/100k/048709.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._048709.jpg
#   inflating: celeb_images_base/100k/100k/071188.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._071188.jpg
#   inflating: celeb_images_base/100k/100k/196707.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._196707.jpg
#   inflating: celeb_images_base/100k/100k/142230.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._142230.jpg
#   inflating: celeb_images_base/100k/100k/046724.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._046724.jpg
#   inflating: celeb_images_base/100k/100k/092213.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._092213.jpg
#   inflating: celeb_images_base/100k/100k/144899.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._144899.jpg
#   inflating: celeb_images_base/100k/100k/113719.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._113719.jpg
#   inflating: celeb_images_base/100k/100k/114076.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._114076.jpg
#   inflating: celeb_images_base/100k/100k/152023.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._152023.jpg
#   inflating: celeb_images_base/100k/100k/010562.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._010562.jpg
#   inflating: celeb_images_base/100k/100k/200905.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._200905.jpg
#   inflating: celeb_images_base/100k/100k/059604.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._059604.jpg
#   inflating: celeb_images_base/100k/100k/191068.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._191068.jpg
#   inflating: celeb_images_base/100k/100k/056251.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056251.jpg
#   inflating: celeb_images_base/100k/100k/114710.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._114710.jpg
#   inflating: celeb_images_base/100k/100k/082766.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._082766.jpg
#   inflating: celeb_images_base/100k/100k/186272.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._186272.jpg
#   inflating: celeb_images_base/100k/100k/143890.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._143890.jpg
#   inflating: celeb_images_base/100k/100k/152745.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._152745.jpg
#   inflating: celeb_images_base/100k/100k/007778.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._007778.jpg
#   inflating: celeb_images_base/100k/100k/076181.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._076181.jpg
#   inflating: celeb_images_base/100k/100k/145239.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._145239.jpg
#   inflating: celeb_images_base/100k/100k/000017.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._000017.jpg
#   inflating: celeb_images_base/100k/100k/196061.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._196061.jpg
#   inflating: celeb_images_base/100k/100k/104503.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._104503.jpg
#   inflating: celeb_images_base/100k/100k/038588.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._038588.jpg
#   inflating: celeb_images_base/100k/100k/066392.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._066392.jpg
#   inflating: celeb_images_base/100k/100k/162686.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._162686.jpg
#   inflating: celeb_images_base/100k/100k/001309.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._001309.jpg
#   inflating: celeb_images_base/100k/100k/143648.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._143648.jpg
#   inflating: celeb_images_base/100k/100k/050620.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050620.jpg
#   inflating: celeb_images_base/100k/100k/163598.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._163598.jpg
#   inflating: celeb_images_base/100k/100k/016675.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._016675.jpg
#   inflating: celeb_images_base/100k/100k/154334.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._154334.jpg
#   inflating: celeb_images_base/100k/100k/028943.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._028943.jpg
#   inflating: celeb_images_base/100k/100k/071836.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._071836.jpg
#   inflating: celeb_images_base/100k/100k/018880.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._018880.jpg
#   inflating: celeb_images_base/100k/100k/006466.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._006466.jpg
#   inflating: celeb_images_base/100k/100k/029485.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._029485.jpg
#   inflating: celeb_images_base/100k/100k/102172.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._102172.jpg
#   inflating: celeb_images_base/100k/100k/193119.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._193119.jpg
#   inflating: celeb_images_base/100k/100k/119234.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._119234.jpg
#   inflating: celeb_images_base/100k/100k/065843.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._065843.jpg
#   inflating: celeb_images_base/100k/100k/054446.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054446.jpg
#   inflating: celeb_images_base/100k/100k/080171.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080171.jpg
#   inflating: celeb_images_base/100k/100k/012413.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._012413.jpg
#   inflating: celeb_images_base/100k/100k/150152.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._150152.jpg
#   inflating: celeb_images_base/100k/100k/109027.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._109027.jpg
#   inflating: celeb_images_base/100k/100k/064585.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._064585.jpg
#   inflating: celeb_images_base/100k/100k/053329.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._053329.jpg
#   inflating: celeb_images_base/100k/100k/194676.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._194676.jpg
#   inflating: celeb_images_base/100k/100k/086500.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._086500.jpg
#   inflating: celeb_images_base/100k/100k/014062.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014062.jpg
#   inflating: celeb_images_base/100k/100k/182014.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._182014.jpg
#   inflating: celeb_images_base/100k/100k/156523.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156523.jpg
#   inflating: celeb_images_base/100k/100k/167926.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167926.jpg
#   inflating: celeb_images_base/100k/100k/195568.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._195568.jpg
#   inflating: celeb_images_base/100k/100k/121973.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._121973.jpg
#   inflating: celeb_images_base/100k/100k/089633.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._089633.jpg
#   inflating: celeb_images_base/100k/100k/146730.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146730.jpg
#   inflating: celeb_images_base/100k/100k/004271.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004271.jpg
#   inflating: celeb_images_base/100k/100k/178806.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._178806.jpg
#   inflating: celeb_images_base/100k/100k/096713.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._096713.jpg
#   inflating: celeb_images_base/100k/100k/099420.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099420.jpg
#   inflating: celeb_images_base/100k/100k/117219.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._117219.jpg
#   inflating: celeb_images_base/100k/100k/055758.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._055758.jpg
#   inflating: celeb_images_base/100k/100k/023802.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._023802.jpg
#   inflating: celeb_images_base/100k/100k/150146.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._150146.jpg
#   inflating: celeb_images_base/100k/100k/080165.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080165.jpg
#   inflating: celeb_images_base/100k/100k/116113.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._116113.jpg
#   inflating: celeb_images_base/100k/100k/054452.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054452.jpg
#   inflating: celeb_images_base/100k/100k/015368.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._015368.jpg
#   inflating: celeb_images_base/100k/100k/157629.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._157629.jpg
#   inflating: celeb_images_base/100k/100k/002614.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._002614.jpg
#   inflating: celeb_images_base/100k/100k/140355.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._140355.jpg
#   inflating: celeb_images_base/100k/100k/156537.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156537.jpg
#   inflating: celeb_images_base/100k/100k/182000.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._182000.jpg
#   inflating: celeb_images_base/100k/100k/014076.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014076.jpg
#   inflating: celeb_images_base/100k/100k/091068.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._091068.jpg
#   inflating: celeb_images_base/100k/100k/167932.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167932.jpg
#   inflating: celeb_images_base/100k/100k/042230.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._042230.jpg
#   inflating: celeb_images_base/100k/100k/171188.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._171188.jpg
#   inflating: celeb_images_base/100k/100k/096707.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._096707.jpg
#   inflating: celeb_images_base/100k/100k/100771.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._100771.jpg
#   inflating: celeb_images_base/100k/100k/004265.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004265.jpg
#   inflating: celeb_images_base/100k/100k/146724.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146724.jpg
#   inflating: celeb_images_base/100k/100k/149417.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._149417.jpg
#   inflating: celeb_images_base/100k/100k/044899.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._044899.jpg
#   inflating: celeb_images_base/100k/100k/013719.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._013719.jpg
#   inflating: celeb_images_base/100k/100k/099434.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099434.jpg
#   inflating: celeb_images_base/100k/100k/059176.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._059176.jpg
#   inflating: celeb_images_base/100k/100k/103278.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._103278.jpg
#   inflating: celeb_images_base/100k/100k/189155.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._189155.jpg
#   inflating: celeb_images_base/100k/100k/046056.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._046056.jpg
#   inflating: celeb_images_base/100k/100k/092561.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._092561.jpg
#   inflating: celeb_images_base/100k/100k/009999.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._009999.jpg
#   inflating: celeb_images_base/100k/100k/000003.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._000003.jpg
#   inflating: celeb_images_base/100k/100k/181509.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._181509.jpg
#   inflating: celeb_images_base/100k/100k/049365.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._049365.jpg
#   inflating: celeb_images_base/100k/100k/047348.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._047348.jpg
#   inflating: celeb_images_base/100k/100k/154320.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._154320.jpg
#   inflating: celeb_images_base/100k/100k/180617.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._180617.jpg
#   inflating: celeb_images_base/100k/100k/067098.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._067098.jpg
#   inflating: celeb_images_base/100k/100k/016661.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._016661.jpg
#   inflating: celeb_images_base/100k/100k/112375.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._112375.jpg
#   inflating: celeb_images_base/100k/100k/084303.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084303.jpg
#   inflating: celeb_images_base/100k/100k/050634.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050634.jpg
#   inflating: celeb_images_base/100k/100k/009741.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._009741.jpg
#   inflating: celeb_images_base/100k/100k/018894.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._018894.jpg
#   inflating: celeb_images_base/100k/100k/187178.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._187178.jpg
#   inflating: celeb_images_base/100k/100k/040427.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._040427.jpg
#   inflating: celeb_images_base/100k/100k/094110.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._094110.jpg
#   inflating: celeb_images_base/100k/100k/029491.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._029491.jpg
#   inflating: celeb_images_base/100k/100k/144133.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._144133.jpg
#   inflating: celeb_images_base/100k/100k/009027.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._009027.jpg
#   inflating: celeb_images_base/100k/100k/060091.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._060091.jpg
#   inflating: celeb_images_base/100k/100k/094676.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._094676.jpg
#   inflating: celeb_images_base/100k/100k/102600.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._102600.jpg
#   inflating: celeb_images_base/100k/100k/040341.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._040341.jpg
#   inflating: celeb_images_base/100k/100k/123816.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._123816.jpg
#   inflating: celeb_images_base/100k/100k/019234.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._019234.jpg
#   inflating: celeb_images_base/100k/100k/050152.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050152.jpg
#   inflating: celeb_images_base/100k/100k/084465.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084465.jpg
#   inflating: celeb_images_base/100k/100k/175488.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._175488.jpg
#   inflating: celeb_images_base/100k/100k/196713.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._196713.jpg
#   inflating: celeb_images_base/100k/100k/199420.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._199420.jpg
#   inflating: celeb_images_base/100k/100k/017219.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._017219.jpg
#   inflating: celeb_images_base/100k/100k/049403.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._049403.jpg
#   inflating: celeb_images_base/100k/100k/114062.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._114062.jpg
#   inflating: celeb_images_base/100k/100k/067926.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._067926.jpg
#   inflating: celeb_images_base/100k/100k/189633.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._189633.jpg
#   inflating: celeb_images_base/100k/100k/021973.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._021973.jpg
#   inflating: celeb_images_base/100k/100k/146042.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146042.jpg
#   inflating: celeb_images_base/100k/100k/004503.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004503.jpg
#   inflating: celeb_images_base/100k/100k/138588.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._138588.jpg
#   inflating: celeb_images_base/100k/100k/149371.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._149371.jpg
#   inflating: celeb_images_base/100k/100k/035906.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._035906.jpg
#   inflating: celeb_images_base/100k/100k/166392.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._166392.jpg
#   inflating: celeb_images_base/100k/100k/185009.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._185009.jpg
#   inflating: celeb_images_base/100k/100k/014710.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014710.jpg
#   inflating: celeb_images_base/100k/100k/156251.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156251.jpg
#   inflating: celeb_images_base/100k/100k/110204.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._110204.jpg
#   inflating: celeb_images_base/100k/100k/086272.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._086272.jpg
#   inflating: celeb_images_base/100k/100k/072495.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._072495.jpg
#   inflating: celeb_images_base/100k/100k/089141.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._089141.jpg
#   inflating: celeb_images_base/100k/100k/045239.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._045239.jpg
#   inflating: celeb_images_base/100k/100k/107778.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._107778.jpg
#   inflating: celeb_images_base/100k/100k/171836.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._171836.jpg
#   inflating: celeb_images_base/100k/100k/109755.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._109755.jpg
#   inflating: celeb_images_base/100k/100k/183478.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._183478.jpg
#   inflating: celeb_images_base/100k/100k/118880.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._118880.jpg
#   inflating: celeb_images_base/100k/100k/090410.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._090410.jpg
#   inflating: celeb_images_base/100k/100k/129485.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._129485.jpg
#   inflating: celeb_images_base/100k/100k/140433.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._140433.jpg
#   inflating: celeb_images_base/100k/100k/043648.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._043648.jpg
#   inflating: celeb_images_base/100k/100k/012361.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._012361.jpg
#   inflating: celeb_images_base/100k/100k/184317.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._184317.jpg
#   inflating: celeb_images_base/100k/100k/054334.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054334.jpg
#   inflating: celeb_images_base/100k/100k/080603.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080603.jpg
#   inflating: celeb_images_base/100k/100k/116675.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._116675.jpg
#   inflating: celeb_images_base/100k/100k/139696.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._139696.jpg
#   inflating: celeb_images_base/100k/100k/064778.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._064778.jpg
#   inflating: celeb_images_base/100k/100k/015181.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._015181.jpg
#   inflating: celeb_images_base/100k/100k/126239.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._126239.jpg
#   inflating: celeb_images_base/100k/100k/178423.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._178423.jpg
#   inflating: celeb_images_base/100k/100k/099805.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099805.jpg
#   inflating: celeb_images_base/100k/100k/073204.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._073204.jpg
#   inflating: celeb_images_base/100k/100k/131745.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._131745.jpg
#   inflating: celeb_images_base/100k/100k/177710.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._177710.jpg
#   inflating: celeb_images_base/100k/100k/086925.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._086925.jpg
#   inflating: celeb_images_base/100k/100k/110953.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._110953.jpg
#   inflating: celeb_images_base/100k/100k/167503.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167503.jpg
#   inflating: celeb_images_base/100k/100k/139319.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._139319.jpg
#   inflating: celeb_images_base/100k/100k/121556.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._121556.jpg
#   inflating: celeb_images_base/100k/100k/184698.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._184698.jpg
#   inflating: celeb_images_base/100k/100k/063017.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._063017.jpg
#   inflating: celeb_images_base/100k/100k/137334.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._137334.jpg
#   inflating: celeb_images_base/100k/100k/100598.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._100598.jpg
#   inflating: celeb_images_base/100k/100k/062309.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._062309.jpg
#   inflating: celeb_images_base/100k/100k/088908.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._088908.jpg
#   inflating: celeb_images_base/100k/100k/138007.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._138007.jpg
#   inflating: celeb_images_base/100k/100k/097828.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._097828.jpg
#   inflating: celeb_images_base/100k/100k/128214.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._128214.jpg
#   inflating: celeb_images_base/100k/100k/012836.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._012836.jpg
#   inflating: celeb_images_base/100k/100k/037446.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._037446.jpg
#   inflating: celeb_images_base/100k/100k/175107.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._175107.jpg
#   inflating: celeb_images_base/100k/100k/017796.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._017796.jpg
#   inflating: celeb_images_base/100k/100k/038775.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._038775.jpg
#   inflating: celeb_images_base/100k/100k/006843.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._006843.jpg
#   inflating: celeb_images_base/100k/100k/165314.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._165314.jpg
#   inflating: celeb_images_base/100k/100k/019963.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._019963.jpg
#   inflating: celeb_images_base/100k/100k/123341.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._123341.jpg
#   inflating: celeb_images_base/100k/100k/061600.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._061600.jpg
#   inflating: celeb_images_base/100k/100k/172668.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._172668.jpg
#   inflating: celeb_images_base/100k/100k/103091.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._103091.jpg
#   inflating: celeb_images_base/100k/100k/030329.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._030329.jpg
#   inflating: celeb_images_base/100k/100k/007585.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._007585.jpg
#   inflating: celeb_images_base/100k/100k/142973.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._142973.jpg
#   inflating: celeb_images_base/100k/100k/078351.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._078351.jpg
#   inflating: celeb_images_base/100k/100k/092950.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._092950.jpg
#   inflating: celeb_images_base/100k/100k/104926.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._104926.jpg
#   inflating: celeb_images_base/100k/100k/058081.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._058081.jpg
#   inflating: celeb_images_base/100k/100k/029678.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._029678.jpg
#   inflating: celeb_images_base/100k/100k/181938.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._181938.jpg
#   inflating: celeb_images_base/100k/100k/031037.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._031037.jpg
#   inflating: celeb_images_base/100k/100k/173576.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._173576.jpg
#   inflating: celeb_images_base/100k/100k/197182.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._197182.jpg
#   inflating: celeb_images_base/100k/100k/067271.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._067271.jpg
#   inflating: celeb_images_base/100k/100k/068624.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._068624.jpg
#   inflating: celeb_images_base/100k/100k/186931.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._186931.jpg
#   inflating: celeb_images_base/100k/100k/095959.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._095959.jpg
#   inflating: celeb_images_base/100k/100k/021542.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._021542.jpg
#   inflating: celeb_images_base/100k/100k/163003.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._163003.jpg
#   inflating: celeb_images_base/100k/100k/067517.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._067517.jpg
#   inflating: celeb_images_base/100k/100k/122739.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._122739.jpg
#   inflating: celeb_images_base/100k/100k/060278.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._060278.jpg
#   inflating: celeb_images_base/100k/100k/115195.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._115195.jpg
#   inflating: celeb_images_base/100k/100k/049832.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._049832.jpg
#   inflating: celeb_images_base/100k/100k/135245.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._135245.jpg
#   inflating: celeb_images_base/100k/100k/020884.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._020884.jpg
#   inflating: celeb_images_base/100k/100k/199811.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._199811.jpg
#   inflating: celeb_images_base/100k/100k/027133.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._027133.jpg
#   inflating: celeb_images_base/100k/100k/165472.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._165472.jpg
#   inflating: celeb_images_base/100k/100k/061166.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._061166.jpg
#   inflating: celeb_images_base/100k/100k/084854.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084854.jpg
#   inflating: celeb_images_base/100k/100k/095781.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._095781.jpg
#   inflating: celeb_images_base/100k/100k/038013.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._038013.jpg
#   inflating: celeb_images_base/100k/100k/085592.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._085592.jpg
#   inflating: celeb_images_base/100k/100k/023355.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._023355.jpg
#   inflating: celeb_images_base/100k/100k/202337.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._202337.jpg
#   inflating: celeb_images_base/100k/100k/136994.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._136994.jpg
#   inflating: celeb_images_base/100k/100k/176368.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._176368.jpg
#   inflating: celeb_images_base/100k/100k/003085.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._003085.jpg
#   inflating: celeb_images_base/100k/100k/183849.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._183849.jpg
#   inflating: celeb_images_base/100k/100k/137452.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._137452.jpg
#   inflating: celeb_images_base/100k/100k/171407.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._171407.jpg
#   inflating: celeb_images_base/100k/100k/033146.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._033146.jpg
#   inflating: celeb_images_base/100k/100k/140802.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._140802.jpg
#   inflating: celeb_images_base/100k/100k/138761.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._138761.jpg
#   inflating: celeb_images_base/100k/100k/170719.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._170719.jpg
#   inflating: celeb_images_base/100k/100k/193482.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._193482.jpg
#   inflating: celeb_images_base/100k/100k/168156.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._168156.jpg
#   inflating: celeb_images_base/100k/100k/167265.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167265.jpg
#   inflating: celeb_images_base/100k/100k/063771.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._063771.jpg
#   inflating: celeb_images_base/100k/100k/121230.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._121230.jpg
#   inflating: celeb_images_base/100k/100k/192944.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._192944.jpg
#   inflating: celeb_images_base/100k/100k/004932.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004932.jpg
#   inflating: celeb_images_base/100k/100k/183691.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._183691.jpg
#   inflating: celeb_images_base/100k/100k/131023.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._131023.jpg
#   inflating: celeb_images_base/100k/100k/035537.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._035537.jpg
#   inflating: celeb_images_base/100k/100k/065314.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._065314.jpg
#   inflating: celeb_images_base/100k/100k/202323.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._202323.jpg
#   inflating: celeb_images_base/100k/100k/136980.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._136980.jpg
#   inflating: celeb_images_base/100k/100k/161600.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._161600.jpg
#   inflating: celeb_images_base/100k/100k/023341.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._023341.jpg
#   inflating: celeb_images_base/100k/100k/072668.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._072668.jpg
#   inflating: celeb_images_base/100k/100k/107585.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._107585.jpg
#   inflating: celeb_images_base/100k/100k/128566.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._128566.jpg
#   inflating: celeb_images_base/100k/100k/033152.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._033152.jpg
#   inflating: celeb_images_base/100k/100k/192788.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._192788.jpg
#   inflating: celeb_images_base/100k/100k/090835.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._090835.jpg
#   inflating: celeb_images_base/100k/100k/117796.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._117796.jpg
#   inflating: celeb_images_base/100k/100k/136758.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._136758.jpg
#   inflating: celeb_images_base/100k/100k/097182.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._097182.jpg
#   inflating: celeb_images_base/100k/100k/121224.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._121224.jpg
#   inflating: celeb_images_base/100k/100k/063765.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._063765.jpg
#   inflating: celeb_images_base/100k/100k/148292.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._148292.jpg
#   inflating: celeb_images_base/100k/100k/025730.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._025730.jpg
#   inflating: celeb_images_base/100k/100k/183685.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._183685.jpg
#   inflating: celeb_images_base/100k/100k/004926.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004926.jpg
#   inflating: celeb_images_base/100k/100k/035523.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._035523.jpg
#   inflating: celeb_images_base/100k/100k/158081.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._158081.jpg
#   inflating: celeb_images_base/100k/100k/177062.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._177062.jpg
#   inflating: celeb_images_base/100k/100k/073576.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._073576.jpg
#   inflating: celeb_images_base/100k/100k/056906.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056906.jpg
#   inflating: celeb_images_base/100k/100k/125042.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._125042.jpg
#   inflating: celeb_images_base/100k/100k/039319.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._039319.jpg
#   inflating: celeb_images_base/100k/100k/084698.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084698.jpg
#   inflating: celeb_images_base/100k/100k/021556.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._021556.jpg
#   inflating: celeb_images_base/100k/100k/026239.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._026239.jpg
#   inflating: celeb_images_base/100k/100k/115181.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._115181.jpg
#   inflating: celeb_images_base/100k/100k/164778.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._164778.jpg
#   inflating: celeb_images_base/100k/100k/011495.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._011495.jpg
#   inflating: celeb_images_base/100k/100k/031745.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._031745.jpg
#   inflating: celeb_images_base/100k/100k/123433.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._123433.jpg
#   inflating: celeb_images_base/100k/100k/061172.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._061172.jpg
#   inflating: celeb_images_base/100k/100k/165466.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._165466.jpg
#   inflating: celeb_images_base/100k/100k/027127.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._027127.jpg
#   inflating: celeb_images_base/100k/100k/028214.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._028214.jpg
#   inflating: celeb_images_base/100k/100k/191281.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._191281.jpg
#   inflating: celeb_images_base/100k/100k/095795.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._095795.jpg
#   inflating: celeb_images_base/100k/100k/175675.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._175675.jpg
#   inflating: celeb_images_base/100k/100k/071361.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._071361.jpg
#   inflating: celeb_images_base/100k/100k/000598.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._000598.jpg
#   inflating: celeb_images_base/100k/100k/133620.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._133620.jpg
#   inflating: celeb_images_base/100k/100k/020648.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._020648.jpg
#   inflating: celeb_images_base/100k/100k/188908.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._188908.jpg
#   inflating: celeb_images_base/100k/100k/038007.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._038007.jpg
#   inflating: celeb_images_base/100k/100k/175113.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._175113.jpg
#   inflating: celeb_images_base/100k/100k/069248.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._069248.jpg
#   inflating: celeb_images_base/100k/100k/083849.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._083849.jpg
#   inflating: celeb_images_base/100k/100k/133146.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._133146.jpg
#   inflating: celeb_images_base/100k/100k/006857.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._006857.jpg
#   inflating: celeb_images_base/100k/100k/190821.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._190821.jpg
#   inflating: celeb_images_base/100k/100k/049198.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._049198.jpg
#   inflating: celeb_images_base/100k/100k/017782.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._017782.jpg
#   inflating: celeb_images_base/100k/100k/123355.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._123355.jpg
#   inflating: celeb_images_base/100k/100k/027641.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._027641.jpg
#   inflating: celeb_images_base/100k/100k/165300.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._165300.jpg
#   inflating: celeb_images_base/100k/100k/076368.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._076368.jpg
#   inflating: celeb_images_base/100k/100k/007591.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._007591.jpg
#   inflating: celeb_images_base/100k/100k/083691.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._083691.jpg
#   inflating: celeb_images_base/100k/100k/104932.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._104932.jpg
#   inflating: celeb_images_base/100k/100k/078345.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._078345.jpg
#   inflating: celeb_images_base/100k/100k/187385.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._187385.jpg
#   inflating: celeb_images_base/100k/100k/142967.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._142967.jpg
#   inflating: celeb_images_base/100k/100k/173562.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._173562.jpg
#   inflating: celeb_images_base/100k/100k/135537.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._135537.jpg
#   inflating: celeb_images_base/100k/100k/021230.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._021230.jpg
#   inflating: celeb_images_base/100k/100k/112188.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._112188.jpg
#   inflating: celeb_images_base/100k/100k/163771.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._163771.jpg
#   inflating: celeb_images_base/100k/100k/111481.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._111481.jpg
#   inflating: celeb_images_base/100k/100k/022739.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._022739.jpg
#   inflating: celeb_images_base/100k/100k/177704.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._177704.jpg
#   inflating: celeb_images_base/100k/100k/035245.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._035245.jpg
#   inflating: celeb_images_base/100k/100k/073210.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._073210.jpg
#   inflating: celeb_images_base/100k/100k/099811.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099811.jpg
#   inflating: celeb_images_base/100k/100k/156912.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156912.jpg
#   inflating: celeb_images_base/100k/100k/110947.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._110947.jpg
#   inflating: celeb_images_base/100k/100k/101692.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._101692.jpg
#   inflating: celeb_images_base/100k/100k/080398.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080398.jpg
#   inflating: celeb_images_base/100k/100k/167517.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167517.jpg
#   inflating: celeb_images_base/100k/100k/171375.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._171375.jpg
#   inflating: celeb_images_base/100k/100k/004098.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004098.jpg
#   inflating: celeb_images_base/100k/100k/202445.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._202445.jpg
#   inflating: celeb_images_base/100k/100k/127133.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._127133.jpg
#   inflating: celeb_images_base/100k/100k/179729.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._179729.jpg
#   inflating: celeb_images_base/100k/100k/023427.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._023427.jpg
#   inflating: celeb_images_base/100k/100k/054877.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054877.jpg
#   inflating: celeb_images_base/100k/100k/091295.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._091295.jpg
#   inflating: celeb_images_base/100k/100k/128200.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._128200.jpg
#   inflating: celeb_images_base/100k/100k/066153.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._066153.jpg
#   inflating: celeb_images_base/100k/100k/038749.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._038749.jpg
#   inflating: celeb_images_base/100k/100k/124412.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._124412.jpg
#   inflating: celeb_images_base/100k/100k/190809.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._190809.jpg
#   inflating: celeb_images_base/100k/100k/020106.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._020106.jpg
#   inflating: celeb_images_base/100k/100k/153842.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._153842.jpg
#   inflating: celeb_images_base/100k/100k/115817.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._115817.jpg
#   inflating: celeb_images_base/100k/100k/018499.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._018499.jpg
#   inflating: celeb_images_base/100k/100k/069260.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._069260.jpg
#   inflating: celeb_images_base/100k/100k/189380.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._189380.jpg
#   inflating: celeb_images_base/100k/100k/163981.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._163981.jpg
#   inflating: celeb_images_base/100k/100k/134601.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._134601.jpg
#   inflating: celeb_images_base/100k/100k/076340.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._076340.jpg
#   inflating: celeb_images_base/100k/100k/056090.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056090.jpg
#   inflating: celeb_images_base/100k/100k/152584.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._152584.jpg
#   inflating: celeb_images_base/100k/100k/017972.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._017972.jpg
#   inflating: celeb_images_base/100k/100k/009594.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._009594.jpg
#   inflating: celeb_images_base/100k/100k/164036.jpg
# ...
#   inflating: celeb_images_base/100k/100k/056325.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056325.jpg
#   inflating: celeb_images_base/100k/100k/103318.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._103318.jpg
#   inflating: celeb_images_base/100k/100k/189035.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._189035.jpg
#   inflating: celeb_images_base/100k/100k/042350.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._042350.jpg
#   inflating: celeb_images_base/100k/100k/100611.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._100611.jpg
#   inflating: celeb_images_base/100k/100k/004305.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._004305.jpg
#   inflating: celeb_images_base/100k/100k/192373.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._192373.jpg
#   inflating: celeb_images_base/100k/100k/146644.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146644.jpg
#   inflating: celeb_images_base/100k/100k/166594.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._166594.jpg
#   inflating: celeb_images_base/100k/100k/062080.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._062080.jpg
#   inflating: celeb_images_base/100k/100k/151338.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._151338.jpg
#   inflating: celeb_images_base/100k/100k/156457.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156457.jpg
#   inflating: celeb_images_base/100k/100k/182160.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._182160.jpg
#   inflating: celeb_images_base/100k/100k/014116.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014116.jpg
#   inflating: celeb_images_base/100k/100k/086474.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._086474.jpg
#   inflating: celeb_images_base/100k/100k/089747.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._089747.jpg
#   inflating: celeb_images_base/100k/100k/098892.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._098892.jpg
#   inflating: celeb_images_base/100k/100k/159764.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._159764.jpg
#   inflating: celeb_images_base/100k/100k/157749.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._157749.jpg
#   inflating: celeb_images_base/100k/100k/109153.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._109153.jpg
#   inflating: celeb_images_base/100k/100k/090216.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._090216.jpg
#   inflating: celeb_images_base/100k/100k/177499.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._177499.jpg
#   inflating: celeb_images_base/100k/100k/129283.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._129283.jpg
#   inflating: celeb_images_base/100k/100k/002774.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._002774.jpg
#   inflating: celeb_images_base/100k/100k/065937.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._065937.jpg
#   inflating: celeb_images_base/100k/100k/119340.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._119340.jpg
#   inflating: celeb_images_base/100k/100k/023962.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._023962.jpg
#   inflating: celeb_images_base/100k/100k/184511.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._184511.jpg
#   inflating: celeb_images_base/100k/100k/148669.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._148669.jpg
#   inflating: celeb_images_base/100k/100k/054532.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054532.jpg
#   inflating: celeb_images_base/100k/100k/146650.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146650.jpg
#   inflating: celeb_images_base/100k/100k/157985.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._157985.jpg
#   inflating: celeb_images_base/100k/100k/100605.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._100605.jpg
#   inflating: celeb_images_base/100k/100k/096673.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._096673.jpg
#   inflating: celeb_images_base/100k/100k/099540.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._099540.jpg
#   inflating: celeb_images_base/100k/100k/062094.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._062094.jpg
#   inflating: celeb_images_base/100k/100k/149563.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._149563.jpg
#   inflating: celeb_images_base/100k/100k/055638.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._055638.jpg
#   inflating: celeb_images_base/100k/100k/086460.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._086460.jpg
#   inflating: celeb_images_base/100k/100k/014102.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014102.jpg
#   inflating: celeb_images_base/100k/100k/108259.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._108259.jpg
#   inflating: celeb_images_base/100k/100k/167846.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._167846.jpg
#   inflating: celeb_images_base/100k/100k/176793.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._176793.jpg
#   inflating: celeb_images_base/100k/100k/128189.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._128189.jpg
#   inflating: celeb_images_base/100k/100k/111708.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._111708.jpg
#   inflating: celeb_images_base/100k/100k/140221.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._140221.jpg
#   inflating: celeb_images_base/100k/100k/106274.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._106274.jpg
#   inflating: celeb_images_base/100k/100k/119354.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._119354.jpg
#   inflating: celeb_images_base/100k/100k/065923.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._065923.jpg
#   inflating: celeb_images_base/100k/100k/054526.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054526.jpg
#   inflating: celeb_images_base/100k/100k/139084.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._139084.jpg
#   inflating: celeb_images_base/100k/100k/080011.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080011.jpg
#   inflating: celeb_images_base/100k/100k/060683.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._060683.jpg
#   inflating: celeb_images_base/100k/100k/037903.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._037903.jpg
#   inflating: celeb_images_base/100k/100k/144047.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._144047.jpg
#   inflating: celeb_images_base/100k/100k/190570.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._190570.jpg
#   inflating: celeb_images_base/100k/100k/006506.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._006506.jpg
#   inflating: celeb_images_base/100k/100k/019426.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._019426.jpg
#   inflating: celeb_images_base/100k/100k/001269.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._001269.jpg
#   inflating: celeb_images_base/100k/100k/143728.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._143728.jpg
#   inflating: celeb_images_base/100k/100k/050740.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050740.jpg
#   inflating: celeb_images_base/100k/100k/084277.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084277.jpg
#   inflating: celeb_images_base/100k/100k/112201.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._112201.jpg
#   inflating: celeb_images_base/100k/100k/028823.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._028823.jpg
#   inflating: celeb_images_base/100k/100k/142436.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._142436.jpg
#   inflating: celeb_images_base/100k/100k/000177.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._000177.jpg
#   inflating: celeb_images_base/100k/100k/018738.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._018738.jpg
#   inflating: celeb_images_base/100k/100k/049211.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._049211.jpg
#   inflating: celeb_images_base/100k/100k/135866.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._135866.jpg
#   inflating: celeb_images_base/100k/100k/199232.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._199232.jpg
#   inflating: celeb_images_base/100k/100k/056331.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056331.jpg
#   inflating: celeb_images_base/100k/100k/114670.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._114670.jpg
#   inflating: celeb_images_base/100k/100k/082606.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._082606.jpg
#   inflating: celeb_images_base/100k/100k/186312.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._186312.jpg
#   inflating: celeb_images_base/100k/100k/152625.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._152625.jpg
#   inflating: celeb_images_base/100k/100k/056457.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._056457.jpg
#   inflating: celeb_images_base/100k/100k/152143.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._152143.jpg
#   inflating: celeb_images_base/100k/100k/186474.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._186474.jpg
#   inflating: celeb_images_base/100k/100k/010402.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._010402.jpg
#   inflating: celeb_images_base/100k/100k/172293.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._172293.jpg
#   inflating: celeb_images_base/100k/100k/189747.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._189747.jpg
#   inflating: celeb_images_base/100k/100k/200865.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._200865.jpg
#   inflating: celeb_images_base/100k/100k/067852.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._067852.jpg
#   inflating: celeb_images_base/100k/100k/076787.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._076787.jpg
#   inflating: celeb_images_base/100k/100k/191108.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._191108.jpg
#   inflating: celeb_images_base/100k/100k/196667.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._196667.jpg
#   inflating: celeb_images_base/100k/100k/142350.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._142350.jpg
#   inflating: celeb_images_base/100k/100k/046644.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._046644.jpg
#   inflating: celeb_images_base/100k/100k/078972.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._078972.jpg
#   inflating: celeb_images_base/100k/100k/057991.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._057991.jpg
#   inflating: celeb_images_base/100k/100k/104305.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._104305.jpg
#   inflating: celeb_images_base/100k/100k/066594.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._066594.jpg
#   inflating: celeb_images_base/100k/100k/051338.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._051338.jpg
#   inflating: celeb_images_base/100k/100k/113679.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._113679.jpg
#   inflating: celeb_images_base/100k/100k/162080.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._162080.jpg
#   inflating: celeb_images_base/100k/100k/197579.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._197579.jpg
#   inflating: celeb_images_base/100k/100k/084511.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._084511.jpg
#   inflating: celeb_images_base/100k/100k/050026.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._050026.jpg
#   inflating: celeb_images_base/100k/100k/154532.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._154532.jpg
#   inflating: celeb_images_base/100k/100k/048669.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._048669.jpg
#   inflating: celeb_images_base/100k/100k/057749.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._057749.jpg
#   inflating: celeb_images_base/100k/100k/115208.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._115208.jpg
#   inflating: celeb_images_base/100k/100k/190216.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._190216.jpg
#   inflating: celeb_images_base/100k/100k/006260.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._006260.jpg
#   inflating: celeb_images_base/100k/100k/029283.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._029283.jpg
#   inflating: celeb_images_base/100k/100k/188459.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._188459.jpg
#   inflating: celeb_images_base/100k/100k/170484.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._170484.jpg
#   inflating: celeb_images_base/100k/100k/119432.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._119432.jpg
#   inflating: celeb_images_base/100k/100k/005769.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._005769.jpg
#   inflating: celeb_images_base/100k/100k/116701.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._116701.jpg
#   inflating: celeb_images_base/100k/100k/080777.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._080777.jpg
#   inflating: celeb_images_base/100k/100k/128837.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._128837.jpg
#   inflating: celeb_images_base/100k/100k/054240.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._054240.jpg
#   inflating: celeb_images_base/100k/100k/150754.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._150754.jpg
#   inflating: celeb_images_base/100k/100k/184263.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._184263.jpg
#   inflating: celeb_images_base/100k/100k/137917.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._137917.jpg
#   inflating: celeb_images_base/100k/100k/109621.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._109621.jpg
#   inflating: celeb_images_base/100k/100k/087018.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._087018.jpg
#   inflating: celeb_images_base/100k/100k/160697.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._160697.jpg
#   inflating: celeb_images_base/100k/100k/194070.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._194070.jpg
#   inflating: celeb_images_base/100k/100k/044053.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._044053.jpg
#   inflating: celeb_images_base/100k/100k/158308.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._158308.jpg
#   inflating: celeb_images_base/100k/100k/090564.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._090564.jpg
#   inflating: celeb_images_base/100k/100k/106512.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._106512.jpg
#   inflating: celeb_images_base/100k/100k/110370.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._110370.jpg
#   inflating: celeb_images_base/100k/100k/052631.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._052631.jpg
#   inflating: celeb_images_base/100k/100k/156325.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._156325.jpg
#   inflating: celeb_images_base/100k/100k/014664.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._014664.jpg
#   inflating: celeb_images_base/100k/100k/182612.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._182612.jpg
#   inflating: celeb_images_base/100k/100k/159016.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._159016.jpg
#   inflating: celeb_images_base/100k/100k/192401.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._192401.jpg
#   inflating: celeb_images_base/100k/100k/146136.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._146136.jpg
#   inflating: celeb_images_base/100k/100k/081469.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._081469.jpg
#   inflating: celeb_images_base/100k/100k/035872.jpg
#   inflating: __MACOSX/celeb_images_base/100k/100k/._035872.jpg

# %%
#Code Block 4
def generator(z, output_channel_dim, training):
    with tf.variable_scope("generator", reuse= not training):
        
        # 8x8x1024
        fully_connected = tf.layers.dense(z, 8*8*1024)
        fully_connected = tf.reshape(fully_connected, (-1, 8, 8, 1024))
        fully_connected = tf.nn.leaky_relu(fully_connected)

        # 8x8x1024 -> 16x16x512
        trans_conv1 = tf.layers.conv2d_transpose(inputs=fully_connected,
                                                 filters=512,
                                                 kernel_size=[5,5],
                                                 strides=[2,2],
                                                 padding="SAME",
                                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                                 name="trans_conv1")
        batch_trans_conv1 = tf.layers.batch_normalization(inputs = trans_conv1,
                                                          training=training,
                                                          epsilon=EPSILON,
                                                          name="batch_trans_conv1")
        trans_conv1_out = tf.nn.leaky_relu(batch_trans_conv1,
                                           name="trans_conv1_out")
        
        # 16x16x512 -> 32x32x256
        trans_conv2 = tf.layers.conv2d_transpose(inputs=trans_conv1_out,
                                                 filters=256,
                                                 kernel_size=[5,5],
                                                 strides=[2,2],
                                                 padding="SAME",
                                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                                 name="trans_conv2")
        batch_trans_conv2 = tf.layers.batch_normalization(inputs = trans_conv2,
                                                          training=training,
                                                          epsilon=EPSILON,
                                                          name="batch_trans_conv2")
        trans_conv2_out = tf.nn.leaky_relu(batch_trans_conv2,
                                           name="trans_conv2_out")
        
        # 32x32x256 -> 64x64x128
        trans_conv3 = tf.layers.conv2d_transpose(inputs=trans_conv2_out,
                                                 filters=128,
                                                 kernel_size=[5,5],
                                                 strides=[2,2],
                                                 padding="SAME",
                                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                                 name="trans_conv3")
        batch_trans_conv3 = tf.layers.batch_normalization(inputs = trans_conv3,
                                                          training=training,
                                                          epsilon=EPSILON,
                                                          name="batch_trans_conv3")
        trans_conv3_out = tf.nn.leaky_relu(batch_trans_conv3,
                                           name="trans_conv3_out")
        
        # 64x64x128 -> 128x128x64
        trans_conv4 = tf.layers.conv2d_transpose(inputs=trans_conv3_out,
                                                 filters=64,
                                                 kernel_size=[5,5],
                                                 strides=[2,2],
                                                 padding="SAME",
                                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                                 name="trans_conv4")
        batch_trans_conv4 = tf.layers.batch_normalization(inputs = trans_conv4,
                                                          training=training,
                                                          epsilon=EPSILON,
                                                          name="batch_trans_conv4")
        trans_conv4_out = tf.nn.leaky_relu(batch_trans_conv4,
                                           name="trans_conv4_out")
        
        # 128x128x64 -> 128x128x3
        logits = tf.layers.conv2d_transpose(inputs=trans_conv4_out,
                                            filters=3,
                                            kernel_size=[5,5],
                                            strides=[1,1],
                                            padding="SAME",
                                            kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                            name="logits")
        out = tf.tanh(logits, name="out")
        return out

# %%
#Code Block 5
def discriminator(x, reuse):
    with tf.variable_scope("discriminator", reuse=reuse): 
        
        # 128*128*3 -> 64x64x64 
        conv1 = tf.layers.conv2d(inputs=x,
                                 filters=64,
                                 kernel_size=[5,5],
                                 strides=[2,2],
                                 padding="SAME",
                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                 name='conv1')
        batch_norm1 = tf.layers.batch_normalization(conv1,
                                                    training=True,
                                                    epsilon=EPSILON,
                                                    name='batch_norm1')
        conv1_out = tf.nn.leaky_relu(batch_norm1,
                                     name="conv1_out")
        
        # 64x64x64-> 32x32x128 
        conv2 = tf.layers.conv2d(inputs=conv1_out,
                                 filters=128,
                                 kernel_size=[5, 5],
                                 strides=[2, 2],
                                 padding="SAME",
                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                 name='conv2')
        batch_norm2 = tf.layers.batch_normalization(conv2,
                                                    training=True,
                                                    epsilon=EPSILON,
                                                    name='batch_norm2')
        conv2_out = tf.nn.leaky_relu(batch_norm2,
                                     name="conv2_out")
        
        # 32x32x128 -> 16x16x256  
        conv3 = tf.layers.conv2d(inputs=conv2_out,
                                 filters=256,
                                 kernel_size=[5, 5],
                                 strides=[2, 2],
                                 padding="SAME",
                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                 name='conv3')
        batch_norm3 = tf.layers.batch_normalization(conv3,
                                                    training=True,
                                                    epsilon=EPSILON,
                                                    name='batch_norm3')
        conv3_out = tf.nn.leaky_relu(batch_norm3,
                                     name="conv3_out")
        
        # 16x16x256 -> 16x16x512
        conv4 = tf.layers.conv2d(inputs=conv3_out,
                                 filters=512,
                                 kernel_size=[5, 5],
                                 strides=[1, 1],
                                 padding="SAME",
                                 kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                 name='conv4')
        batch_norm4 = tf.layers.batch_normalization(conv4,
                                                    training=True,
                                                    epsilon=EPSILON,
                                                    name='batch_norm4')
        conv4_out = tf.nn.leaky_relu(batch_norm4,
                                     name="conv4_out")
        
        # 16x16x512 -> 8x8x1024
        conv5 = tf.layers.conv2d(inputs=conv4_out,
                                filters=1024,
                                kernel_size=[5, 5],
                                strides=[2, 2],
                                padding="SAME",
                                kernel_initializer=tf.truncated_normal_initializer(stddev=WEIGHT_INIT_STDDEV),
                                name='conv5')
        batch_norm5 = tf.layers.batch_normalization(conv5,
                                                    training=True,
                                                    epsilon=EPSILON,
                                                    name='batch_norm5')
        conv5_out = tf.nn.leaky_relu(batch_norm5,
                                     name="conv5_out")

        flatten = tf.reshape(conv5_out, (-1, 8*8*1024))
        logits = tf.layers.dense(inputs=flatten,
                                 units=1,
                                 activation=None)
        out = tf.sigmoid(logits)
        return out, logits

# %%
#Code Block 6
def model_loss(input_real, input_z, output_channel_dim):
    g_model = generator(input_z, output_channel_dim, True)

    noisy_input_real = input_real + tf.random_normal(shape=tf.shape(input_real),
                                                     mean=0.0,
                                                     stddev=random.uniform(0.0, 0.1),
                                                     dtype=tf.float32)
    
    d_model_real, d_logits_real = discriminator(noisy_input_real, reuse=False)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real,
                                                                         labels=tf.ones_like(d_model_real)*random.uniform(0.9, 1.0)))
    d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                         labels=tf.zeros_like(d_model_fake)))
    d_loss = tf.reduce_mean(0.5 * (d_loss_real + d_loss_fake))
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                    labels=tf.ones_like(d_model_fake)))
    return d_loss, g_loss

# %%
#Code Block 7
def model_optimizers(d_loss, g_loss):
    t_vars = tf.trainable_variables()
    g_vars = [var for var in t_vars if var.name.startswith("generator")]
    d_vars = [var for var in t_vars if var.name.startswith("discriminator")]
    
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    gen_updates = [op for op in update_ops if op.name.startswith('generator') or op.name.startswith('discriminator')]
    
    with tf.control_dependencies(gen_updates):
        d_train_opt = tf.train.AdamOptimizer(learning_rate=LR_D, beta1=BETA1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate=LR_G, beta1=BETA1).minimize(g_loss, var_list=g_vars)  
    return d_train_opt, g_train_opt

# %%
#Code Block 8
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None, *real_dim), name='inputs_real')
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name="input_z")
    learning_rate_G = tf.placeholder(tf.float32, name="lr_g")
    learning_rate_D = tf.placeholder(tf.float32, name="lr_d")
    return inputs_real, inputs_z, learning_rate_G, learning_rate_D

# %%
#Code Block 9
def show_samples(sample_images, name, epoch):
    figure, axes = plt.subplots(1, len(sample_images), figsize = (IMAGE_SIZE, IMAGE_SIZE))
    for index, axis in enumerate(axes):
        axis.axis('off')
        image_array = sample_images[index]
        axis.imshow(image_array)
        image = Image.fromarray(image_array)
        image.save(name+"_"+str(epoch)+"_"+str(index)+".png") 
    plt.savefig(name+"_"+str(epoch)+".png", bbox_inches='tight', pad_inches=0)
    plt.show()
    plt.close()

# %%
#Code Block 10
def test(sess, input_z, out_channel_dim, epoch):
    example_z = np.random.uniform(-1, 1, size=[SAMPLES_TO_SHOW, input_z.get_shape().as_list()[-1]])
    samples = sess.run(generator(input_z, out_channel_dim, False), feed_dict={input_z: example_z})
    sample_images = [((sample + 1.0) * 127.5).astype(np.uint8) for sample in samples]
    show_samples(sample_images, OUTPUT_DIR + "samples", epoch)

# %%
#Code Block 11
def summarize_epoch(epoch, sess, d_losses, g_losses, input_z, data_shape, saver):
    print("\nEpoch {}/{}".format(epoch, EPOCHS),
          "\nD Loss: {:.5f}".format(np.mean(d_losses[-MINIBATCH_SIZE:])),
          "\nG Loss: {:.5f}".format(np.mean(g_losses[-MINIBATCH_SIZE:])))
    fig, ax = plt.subplots()
    plt.plot(d_losses, label='Discriminator', alpha=0.6)
    plt.plot(g_losses, label='Generator', alpha=0.6)
    plt.title("Losses")
    plt.legend()
    plt.savefig(OUTPUT_DIR + "losses_" + str(epoch) + ".png")
    plt.show()
    plt.close()
    saver.save(sess, OUTPUT_DIR + "model_" + str(epoch) + ".ckpt")
    test(sess, input_z, data_shape[3], epoch)

# %%
#Code Block 12
def get_batch(dataset):
    files = random.sample(dataset, BATCH_SIZE)
    batch = []
    for file in files:
        if random.choice([True, False]):
            batch.append(np.asarray(Image.open(file).transpose(Image.FLIP_LEFT_RIGHT)))
        else:
            batch.append(np.asarray(Image.open(file)))                     
    batch = np.asarray(batch)
    normalized_batch = (batch / 127.5) - 1.0
    return normalized_batch, files

# %%
#Code Block 13
def train(data_shape, epoch, checkpoint_path):
    input_images, input_z, lr_G, lr_D = model_inputs(data_shape[1:], NOISE_SIZE)
    d_loss, g_loss = model_loss(input_images, input_z, data_shape[3])
    d_opt, g_opt = model_optimizers(d_loss, g_loss)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver()
        if checkpoint_path is not None:
            saver.restore(sess, checkpoint_path)
            
        iteration = 0
        d_losses = []
        g_losses = []
        
        for epoch in range(EPOCH, EPOCHS):        
            epoch += 1
            epoch_dataset = DATASET.copy()
            
            for i in range(MINIBATCH_SIZE):
                iteration_start_time = time.time()
                iteration += 1
                batch_images, used_files = get_batch(epoch_dataset)
                [epoch_dataset.remove(file) for file in used_files]
                
                batch_z = np.random.uniform(-1, 1, size=(BATCH_SIZE, NOISE_SIZE))
                _ = sess.run(d_opt, feed_dict={input_images: batch_images, input_z: batch_z, lr_D: LR_D})
                _ = sess.run(g_opt, feed_dict={input_images: batch_images, input_z: batch_z, lr_G: LR_G})
                d_losses.append(d_loss.eval({input_z: batch_z, input_images: batch_images}))
                g_losses.append(g_loss.eval({input_z: batch_z}))
                
                elapsed_time = round(time.time()-iteration_start_time, 3)
                remaining_files = len(epoch_dataset)
                print("\rEpoch: " + str(epoch) +
                      ", iteration: " + str(iteration) + 
                      ", d_loss: " + str(round(d_losses[-1], 3)) +
                      ", g_loss: " + str(round(g_losses[-1], 3)) +
                      ", duration: " + str(elapsed_time) + 
                      ", minutes remaining: " + str(round(remaining_files/BATCH_SIZE*elapsed_time/60, 1)) +
                      ", remaining files in batch: " + str(remaining_files)
                      , sep=' ', end=' ', flush=True)
                
            summarize_epoch(epoch, sess, d_losses, g_losses, input_z, data_shape, saver)

# %%
#Code Block 14
# Hyperparameters
IMAGE_SIZE = 128
NOISE_SIZE = 100
LR_D = 0.00004
LR_G = 0.0002
BATCH_SIZE = 64
EPOCH = 0 # Non-zero only if we are resuming training with model checkpoint
EPOCHS = 5 #EPOCH + number of epochs to perform
BETA1 = 0.5
WEIGHT_INIT_STDDEV = 0.02
EPSILON = 0.00005
SAMPLES_TO_SHOW = 500

# %%
#Code Block 15
# Data (https://www.kaggle.com/greg115/celebrities-100k)
#/content/100k_temp.txt
BASE_PATH = "/content/celeb_images_base/"
DATASET_LIST_PATH = BASE_PATH + "100k_temp.txt"
INPUT_DATA_DIR = BASE_PATH + "100k/100k/"
OUTPUT_DIR = "/content/drive/MyDrive/DSCI 550 Team Project/Assignment 2/trained_images2/"
DATASET = [INPUT_DATA_DIR + str(line).rstrip() for line in open(DATASET_LIST_PATH,"r")]
#DATASET_SIZE = len(DATASET) 
DATASET_SIZE = 10000
MINIBATCH_SIZE = DATASET_SIZE // BATCH_SIZE

# Optional - model path to resume training
#MODEL_PATH = BASE_PATH + "models/" + "model_" + str(EPOCH) + ".ckpt"

# %%
#Code Block 16
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#Code Block 17
# Training
with tf.Graph().as_default():
    train(data_shape=(DATASET_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3),
          epoch=EPOCH,
          checkpoint_path=None)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   """
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/core.py:261: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/convolutional.py:1736: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/normalization.py:463: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs, training=training)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:61: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: UserWarning: `tf.layers.conv2d_transpose` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2DTranspose` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/convolutional.py:575: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:56: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:60: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:82: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# Epoch: 1, iteration: 156, d_loss: 0.819, g_loss: 0.691, duration: 4.714, minutes remaining: 110.5, remaining files in batch: 90016
# Epoch 1/5
# D Loss: 2.45599
# G Loss: 0.29721
# Epoch: 2, iteration: 312, d_loss: 0.851, g_loss: 0.644, duration: 4.701, minutes remaining: 110.2, remaining files in batch: 90016
# Epoch 2/5
# D Loss: 0.88755
# G Loss: 0.64679
# Epoch: 3, iteration: 468, d_loss: 0.667, g_loss: 0.804, duration: 4.743, minutes remaining: 111.2, remaining files in batch: 90016
# Epoch 3/5
# D Loss: 0.80140
# G Loss: 0.67180
# Epoch: 4, iteration: 624, d_loss: 0.765, g_loss: 0.691, duration: 4.703, minutes remaining: 110.2, remaining files in batch: 90016
# Epoch 4/5
# D Loss: 0.75389
# G Loss: 0.70645
# Epoch: 5, iteration: 780, d_loss: 0.754, g_loss: 0.766, duration: 4.691, minutes remaining: 110.0, remaining files in batch: 90016
# Epoch 5/5
# D Loss: 0.75562
# G Loss: 0.70373
